# %% [markdown]
# ## Tutorial importar imágenes en OpenCV

# %% [markdown]
# 1. **Instalación de OpenCV**: Si aún no tienes instalado OpenCV, puedes hacerlo utilizando pip. Abre tu terminal y escribe el siguiente comando:

# %%
# !pip install opencv-python matplotlib
# Out:
# Requirement already satisfied: opencv-python in c:\users\ruben tocain\appdata\local\programs\python\python312\lib\site-packages (4.10.0.82)
# Collecting matplotlib
#   Downloading matplotlib-3.9.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ruben tocain\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (1.26.4)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.0-cp312-cp312-win_amd64.whl.metadata (165 kB)
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/165.5 kB ? eta -:--:--
#      ------ ------------------------------ 30.7/165.5 kB 330.3 kB/s eta 0:00:01
#      --------- --------------------------- 41.0/165.5 kB 326.8 kB/s eta 0:00:01
#      -------------------- ---------------- 92.2/165.5 kB 525.1 kB/s eta 0:00:01
#      -----------------------------------  163.8/165.5 kB 756.6 kB/s eta 0:00:01
#      ------------------------------------ 165.5/165.5 kB 708.9 kB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\ruben tocain\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.3.0-cp312-cp312-win_amd64.whl.metadata (9.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ruben tocain\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ruben tocain\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.0-cp312-cp312-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#     --------------------------------------- 0.2/8.0 MB 5.9 MB/s eta 0:00:02
#    - -------------------------------------- 0.2/8.0 MB 2.4 MB/s eta 0:00:04
#    -- ------------------------------------- 0.5/8.0 MB 3.5 MB/s eta 0:00:03
#    --- ------------------------------------ 0.6/8.0 MB 3.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.9/8.0 MB 4.0 MB/s eta 0:00:02
#    ------ --------------------------------- 1.2/8.0 MB 4.3 MB/s eta 0:00:02
#    ------- -------------------------------- 1.5/8.0 MB 4.6 MB/s eta 0:00:02
#    -------- ------------------------------- 1.8/8.0 MB 4.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.0/8.0 MB 4.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.2/8.0 MB 4.9 MB/s eta 0:00:02
#    ------------ --------------------------- 2.4/8.0 MB 4.6 MB/s eta 0:00:02
#    ------------- -------------------------- 2.7/8.0 MB 4.8 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.0 MB 5.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.3/8.0 MB 5.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.6/8.0 MB 5.1 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.0 MB 5.2 MB/s eta 0:00:01
#    -------------------- ------------------- 4.1/8.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.4/8.0 MB 5.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.6/8.0 MB 5.3 MB/s eta 0:00:01
#    ------------------------ --------------- 4.9/8.0 MB 5.3 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.0 MB 5.3 MB/s eta 0:00:01
#    --------------------------- ------------ 5.4/8.0 MB 5.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.0 MB 5.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.1/8.0 MB 5.5 MB/s eta 0:00:01
#    -------------------------------- ------- 6.4/8.0 MB 5.5 MB/s eta 0:00:01
#    --------------------------------- ------ 6.7/8.0 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.0/8.0 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------ --- 7.2/8.0 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------- -- 7.5/8.0 MB 5.6 MB/s eta 0:00:01
#    -------------------------------------- - 7.6/8.0 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 5.4 MB/s eta 0:00:00
# Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl (189 kB)
#    ---------------------------------------- 0.0/189.9 kB ? eta -:--:--
#    ---------------------------------------- 189.9/189.9 kB 3.8 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.0-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB 15.4 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.3/2.2 MB 15.4 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.3/2.2 MB 15.4 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.3/2.2 MB 15.4 MB/s eta 0:00:01
#    ------- -------------------------------- 0.4/2.2 MB 1.8 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.2 MB 4.1 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.2 MB 4.1 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.2 MB 3.7 MB/s eta 0:00:01
#    --------------------------- ------------ 1.5/2.2 MB 4.0 MB/s eta 0:00:01
#    --------------------------- ------------ 1.5/2.2 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------ --- 2.0/2.2 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------- -- 2.1/2.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 3.9 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#    ---------------------------------------- 56.0/56.0 kB 2.9 MB/s eta 0:00:00
# Downloading pillow-10.3.0-cp312-cp312-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.5 MB 9.9 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.4/2.5 MB 7.8 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.4/2.5 MB 7.8 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.4/2.5 MB 7.8 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.4/2.5 MB 7.8 MB/s eta 0:00:01
#    ------ --------------------------------- 0.4/2.5 MB 1.4 MB/s eta 0:00:02
#    ------------- -------------------------- 0.8/2.5 MB 2.9 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 6.5 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.0 kiwisolver-1.4.5 matplotlib-3.9.0 pillow-10.3.0 pyparsing-3.1.2

# %% [markdown]
# 2. **Importar las bibliotecas necesarias**: Primero, necesitamos importar las bibliotecas que vamos a utilizar. En este caso, necesitamos `cv2` para OpenCV y `matplotlib` para visualizar la imagen.

# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# 3. **Leer una imagen**: Utilizamos la función `imread` de OpenCV para leer una imagen. La imagen debe estar en el mismo directorio que tu notebook de Jupyter, o necesitas proporcionar la ruta completa a la imagen.

# %%
img = cv2.imread('gato.jpg')

# %% [markdown]
# 4. **Visualizar la imagen**: OpenCV lee las imágenes en formato BGR, pero Matplotlib visualiza las imágenes en formato RGB. Por lo tanto, antes de visualizar la imagen, debemos convertirla de BGR a RGB.

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()
